# %% [markdown]
# Use this script to find all level 1 responders to a fb group post.

# %%
from urllib.request import urlopen
import json
import datetime
import csv
import time
import pandas as pd

# %%
# app_id = "784490488408472"
# app_secret = "97035bf460ccc4734bd1ea2280534047"
# access_token = app_id + "|" + app_secret

access_token = "EAALJfWzkKZAgBACDGJ7SWpGS6nbJB8XnpK2M2otvKw27OjMwhaEvVJeh1JjHCEbkqDbzEOIrCDIFhE7BOvxYBQGYdDDXHEN9Anu8gTKw7lYKMy9HsMga7OqzScZBPYreqLTmVPJTHDiWnvfxlCmC17HZCBZBUdIMzIMrtwmRoQZDZD"

group_name = "afxlowkey"
# urlopen("https://graph.facebook.com/v2.12/me").read()

base = "https://graph.facebook.com/v2.12"
group_query = "/search?q=afxlowkey&type=group"
token = "&access_token=%s" % access_token

# parameters = "/?access_token=%s" % access_token
url = base + group_query + token
url
# Out:
# 'https://graph.facebook.com/v2.12/search?q=afxlowkey&type=group&access_token=EAALJfWzkKZAgBACDGJ7SWpGS6nbJB8XnpK2M2otvKw27OjMwhaEvVJeh1JjHCEbkqDbzEOIrCDIFhE7BOvxYBQGYdDDXHEN9Anu8gTKw7lYKMy9HsMga7OqzScZBPYreqLTmVPJTHDiWnvfxlCmC17HZCBZBUdIMzIMrtwmRoQZDZD'

# %%
# group_name is the name of the group as it appears in the url
# access_token can be attained from Graph API Explorer
def getGroupID(group_name, access_token):
    base = "https://graph.facebook.com/v2.12"
    group_query = "/search?q=%s&type=group" % group_name
    token = "&access_token=%s" % access_token
    url = base + group_query + token
    response = urlopen(url)
#     data = json.loads(resp)
#     return type(response.read())
    data = json.loads(response.read())
    return data["data"][0]["id"]

group_id = getGroupID(group_name, access_token)
group_id
# Out:
# '771531489709530'

# %%
def getPostIDs(group_id):
    base = "https://graph.facebook.com/v2.12/" + group_id
    group_query = "/feed?fields=name"
    token = "&access_token=%s" % access_token
    url = base + group_query + token
    response = urlopen(url)
    data = json.loads(response.read())
    list_of_dicts = data["data"]
    list_of_group_post_ids = [each["id"] for each in list_of_dicts]
    post_order_dict = {}
    iter_range = len(list_of_group_post_ids)
    for i in range(iter_range):
        back = list_of_group_post_ids.pop()
        post_order_dict[i+1] = back
    return post_order_dict
#     return data["data"]

getPostIDs(group_id)
# Out:
# {1: '771531489709530_771531493042863',
#  2: '771531489709530_772063069656372',
#  3: '771531489709530_772063739656305',
#  4: '771531489709530_773875559475123',
#  5: '771531489709530_774127822783230',
#  6: '771531489709530_774772232718789',
#  7: '771531489709530_774788072717205',
#  8: '771531489709530_775124952683517',
#  9: '771531489709530_776401342555878',
#  10: '771531489709530_776490222546990',
#  11: '771531489709530_776559115873434',
#  12: '771531489709530_776816672514345',
#  13: '771531489709530_776489142547098',
#  14: '771531489709530_776968509165828',
#  15: '771531489709530_777313732464639',
#  16: '771531489709530_777310829131596',
#  17: '771531489709530_777280929134586',
#  18: '771531489709530_778279429034736',
#  19: '771531489709530_778829742313038',
#  20: '771531489709530_778418549020824',
#  21: '771531489709530_773784409484238',
#  22: '771531489709530_778228375706508',
#  23: '771531489709530_778940452301967'}

# %%
# string_identifier is a sample string from the post you're looking for.
# use only words (avoid emojis or other ill-formed units of meaning)
string_identifier = """
PRACTICE 6-7 ANNOUNCEMENTS (R.R.)
"""

def findCorrectPost(group_id, string_identifier):
    base = "https://graph.facebook.com/v2.12/" + group_id
    group_query = "/feed?fields=name,message,comments"
    token = "&access_token=%s" % access_token
    url = base + group_query + token
#     print(url)
    response = urlopen(url)
    data = json.loads(response.read())
    correct_post = None
    for post in data["data"]:
#         print(type(list(post.keys())))
        if "message" not in list(post.keys()):
            continue
        check = post["message"]
        identical = False
        for word in string_identifier.split():
            if word not in check:
                break
            identical = True
        if identical:
            print(post["id"])
            correct_post = post
            break
#             print(word)
    
    return correct_post

correct_post = findCorrectPost(group_id, string_identifier)
correct_post
# Out:
# 771531489709530_782438615285484
# {'comments': {'data': [{'created_time': '2018-02-24T23:21:12+0000',
#     'from': {'id': '1997465720283342', 'name': 'Katie Crowe'},
#     'id': '782439565285389',
#     'message': 'no; shooting star social??'},
#    {'created_time': '2018-02-24T23:21:26+0000',
#     'from': {'id': '1941447095868924', 'name': 'Jones Ou'},
#     'id': '782439595285386',
#     'message': 'Yes / Ice Skating??'},
#    {'created_time': '2018-02-24T23:21:31+0000',
#     'from': {'id': '1758146334207622', 'name': 'Victoria Park'},
#     'id': '782439621952050',
#     'message': 'Karaoke yes(terday)\nDry socials: ice skating, movie night, board games'},
#    {'created_time': '2018-02-24T23:22:00+0000',
#     'from': {'id': '1828528500504616', 'name': 'Jaemin Kim'},
#     'id': '782439781952034',
#     'message': 'Yes, board games, poker'},
#    {'created_time': '2018-02-24T23:23:10+0000',
#     'from': {'id': '1365145640257061', 'name': 'Jessica Ji'},
#     'id': '782440075285338',
#     'message': "No / baking together at people's houses"},
#    {'created_time': '2018-02-24T23:24:02+0000',
#     'from': {'id': '2062952267322815', 'name': 'Vincent Tantra'},
#     'id': '782440445285301',
#     'message': 'Yes, boardgames at victory point'},
#    {'created_time': '2018-02-24T23:24:13+0000',
#     'from': {'id': '1812690088775742', 'name': 'Jackie Walia'},
#     'id': '782440505285295',
#     'message': 'Yes! Board game competition, cooking party, trip to sf or somewhere close, trying new foods, fam raves L O L'},
#    {'created_time': '2018-02-24T23:25:12+0000',
#     'from': {'id': '1266859913458317', 'name': 'Andreana Chou'},
#     'id': '782441068618572',
#     'message': 'No, movie night'},
#    {'created_time': '2018-02-24T23:27:04+0000',
#     'from': {'id': '10213485307185861', 'name': 'Eric Liang'},
#     'id': '782441641951848',
#     'message': 'nope, bowling/movies'},
#    {'created_time': '2018-02-24T23:27:41+0000',
#     'from': {'id': '1828224987189314', 'name': 'Vivian Tieu'},
#     'id': '782441771951835',
#     'message': 'Yes, board games, movie night, study sessions'},
#    {'created_time': '2018-02-24T23:28:07+0000',
#     'from': {'id': '1569646543153578', 'name': 'Michelle Leung'},
#     'id': '782441968618482',
#     'message': 'yes, ICE SKATING'},
#    {'created_time': '2018-02-24T23:28:40+0000',
#     'from': {'id': '1966986586649774', 'name': 'Kunal Gosar'},
#     'id': '782442225285123',
#     'message': 'Yes, poker+boardgames'},
#    {'created_time': '2018-02-24T23:29:11+0000',
#     'from': {'id': '1653422644718913', 'name': 'Andrew Low'},
#     'id': '782442418618437',
#     'message': 'No, shooting star'},
#    {'created_time': '2018-02-24T23:29:33+0000',
#     'from': {'id': '10211738622687035', 'name': 'Bill Zhou'},
#     'id': '782442555285090',
#     'message': 'No ice skating'},
#    {'created_time': '2018-02-24T23:29:42+0000',
#     'from': {'id': '845603538945677', 'name': 'Matt Chinn'},
#     'id': '782442615285084',
#     'message': 'No, ice skating/bowling!!'},
#    {'created_time': '2018-02-24T23:30:56+0000',
#     'from': {'id': '1841070009299755', 'name': 'Mina Tran'},
#     'id': '782444728618206',
#     'message': 'Yes, bowling'},
#    {'created_time': '2018-02-24T23:31:02+0000',
#     'from': {'id': '1690561534315880', 'name': 'Izzat Zuhailee'},
#     'id': '782444771951535',
#     'message': 'Yes, trip to sf!'},
#    {'created_time': '2018-02-24T23:33:10+0000',
#     'from': {'id': '1781581091886665', 'name': 'Case-y Takeda'},
#     'id': '782445295284816',
#     'message': 'no, ice skating + sf/oakland/albany trips + bowling + photowalks / photoshoots + hiking + escape room + board games + movie night with projector in dwinelle ? + down for a retreat lmfao'},
#    {'created_time': '2018-02-24T23:33:53+0000',
#     'from': {'id': '1970872972927428', 'name': 'Regina Xu'},
#     'id': '782445461951466',
#     'message': 'yes; boardgames, cooking/baking, sf photoshoot/day trip'},
#    {'created_time': '2018-02-24T23:34:00+0000',
#     'from': {'id': '10212597978288047', 'name': 'Jessica Ji'},
#     'id': '782445511951461',
#     'message': 'No; dance workshop, board game night, ice skating, anime marathon'},
#    {'created_time': '2018-02-24T23:34:43+0000',
#     'from': {'id': '965366800312927', 'name': 'Soo Rim Choi'},
#     'id': '782445821951430',
#     'message': 'yes; ice skating, board games'},
#    {'created_time': '2018-02-24T23:35:19+0000',
#     'from': {'id': '960979860716683', 'name': 'Alex Ro'},
#     'id': '782445968618082',
#     'message': 'Yes; movie night, sf trip'},
#    {'created_time': '2018-02-24T23:35:36+0000',
#     'from': {'id': '402822900142555', 'name': 'Jennifer Hwang'},
#     'id': '782446031951409',
#     'message': 'No, board games or movies'},
#    {'created_time': '2018-02-24T23:37:34+0000',
#     'from': {'id': '10204471685029284', 'name': 'Zhongxia Yan'},
#     'id': '782446441951368',
#     'message': 'no; boardgames, SF'},
#    {'created_time': '2018-02-24T23:38:12+0000',
#     'from': {'id': '10213680222778841', 'name': 'Claire Li'},
#     'id': '782446538618025',
#     'message': 'no, board games, bouldering'}],
#   'paging': {'cursors': {'after': 'WTI5dGJXVnVkRjlqZAFhKemIzSTZAOemd5TkRRMk5UTTROakU0TURJMU9qRTFNVGsxTVRVME9UST0ZD',
#     'before': 'WTI5dGJXVnVkRjlqZAFhKemIzSTZAOemd5TkRNNU5UWTFNamcxTXpnNU9qRTFNVGsxTVRRME56ST0ZD'},
#    'next': 'https://graph.facebook.com/v2.12/771531489709530_782438615285484/comments?access_token=EAALJfWzkKZAgBACDGJ7SWpGS6nbJB8XnpK2M2otvKw27OjMwhaEvVJeh1JjHCEbkqDbzEOIrCDIFhE7BOvxYBQGYdDDXHEN9Anu8gTKw7lYKMy9HsMga7OqzScZBPYreqLTmVPJTHDiWnvfxlCmC17HZCBZBUdIMzIMrtwmRoQZDZD&limit=25&after=WTI5dGJXVnVkRjlqZAFhKemIzSTZAOemd5TkRRMk5UTTROakU0TURJMU9qRTFNVGsxTVRVME9UST0ZD'}},
#  'id': '771531489709530_782438615285484',
#  'message': 'PRACTICE 6-7 ANNOUNCEMENTS (R.R.)\n\nSorry for the late announcements. For those of you who came out yesterday for the social, I hope y’all had fun! ;) NOTE: I will be closing this post tomorrow 2/25 at 12 PM.\n\n1. ~PRACTICE ANNOUNCEMENTS~\n- CASTING: “Otter Pop” AND “Goodies” during practice tomorrow, 2/25 \n- FAM PUNISHMENTS: If you do not read these announcements and answer the reading assignment, your family will have to do punishments with you.\n- THEME: Previous Team Apparel (or just dance related clothing)!\n- LOST AND FOUND: Black puffy jacket from last practice. Message me if it’s yours! Look at “lost1.jpg” for a visual: tinyurl.com/lowkeylostandfound\n\n2. ~KARAOKE + SOCIAL AFTERMATH~\n- If you went to karaoke, please venmo $8.50 to me @Winn-Cui\n- PLEASE BE HONEST!! I have a very good idea of who came out, and don’t want to have to corner you to pay….. >__>\n- DId you go to karaoke yesterday (answer yes/no)? What are some dry socials you want to see us organize in the future?\n\n3. ~MUTEX PREFERENCE FORM~\n- We will close the form by Sunday 11:59 PM: tinyurl.com/lowkeyprefform1\n- We will assume you have “no preference” if it is not sent in by then.\n\n4. ~DIRECTOR INTERN APPS~\n- Apply if you are interested in choreographing, blocking, organizing team logistics, and have dreams of leading a team of your own someday!\n- Due 2/25; Link: tinyurl.com/afxdirectorintern\n\n5. ~TONY RAY HOUSE WORKSHOP + UJI TIME/CHATTE FUNDRAISER~\n- Workshop TODAY @ Haas Pavilion 4-7 PM\n- Workshop Link: fb.com/events/169699810482986/?ti=icl\n- Get a delicious treat before/after the workshop, and mention “AFX Dance” at the counter!!\n- Fundraiser Link: fb.com/events/551878435178526/',
#  'name': 'Lost and Found - Google Drive'}

# %%
def getListOfComments(correct_post):
    
    # TRY BLOCK 1
    comments = []
    data = []
    # Method 1A: getting comments on current page
    try:
#         print("try1")
        data = correct_post["comments"]["data"]
        for comment in data:
            comments.append(comment)
#         print("hsdf", next_page_responders)
    except:
        pass
    
    # Method 2A: getting comments on current page
    try:
        data = correct_post["data"]
        for comment in data:
            comments.append(comment)
    except:
        pass
    
    # TRY BLOCK 2
    url = None
    # Method 1B: accessing the next page of responses
    try:
        url = correct_post["comments"]["paging"]["next"]
    except:
        pass
        
    try:
    # Method 2B: accessing the next page of responses
        url = correct_post["paging"]["next"]
    except:
        pass
    
    # Open the url (found by Method 1B/2B) if it exists.
    next_page_responders = []
    if url:
        response = urlopen(url)
        next_page = json.loads(response.read())
        next_page_responders = getListOfComments(next_page)
        comments.extend(next_page_responders)

    return comments
    

list_of_comments = getListOfComments(correct_post)
list_of_comments
# Out:
# [{'created_time': '2018-02-24T23:21:12+0000',
#   'from': {'id': '1997465720283342', 'name': 'Katie Crowe'},
#   'id': '782439565285389',
#   'message': 'no; shooting star social??'},
#  {'created_time': '2018-02-24T23:21:26+0000',
#   'from': {'id': '1941447095868924', 'name': 'Jones Ou'},
#   'id': '782439595285386',
#   'message': 'Yes / Ice Skating??'},
#  {'created_time': '2018-02-24T23:21:31+0000',
#   'from': {'id': '1758146334207622', 'name': 'Victoria Park'},
#   'id': '782439621952050',
#   'message': 'Karaoke yes(terday)\nDry socials: ice skating, movie night, board games'},
#  {'created_time': '2018-02-24T23:22:00+0000',
#   'from': {'id': '1828528500504616', 'name': 'Jaemin Kim'},
#   'id': '782439781952034',
#   'message': 'Yes, board games, poker'},
#  {'created_time': '2018-02-24T23:23:10+0000',
#   'from': {'id': '1365145640257061', 'name': 'Jessica Ji'},
#   'id': '782440075285338',
#   'message': "No / baking together at people's houses"},
#  {'created_time': '2018-02-24T23:24:02+0000',
#   'from': {'id': '2062952267322815', 'name': 'Vincent Tantra'},
#   'id': '782440445285301',
#   'message': 'Yes, boardgames at victory point'},
#  {'created_time': '2018-02-24T23:24:13+0000',
#   'from': {'id': '1812690088775742', 'name': 'Jackie Walia'},
#   'id': '782440505285295',
#   'message': 'Yes! Board game competition, cooking party, trip to sf or somewhere close, trying new foods, fam raves L O L'},
#  {'created_time': '2018-02-24T23:25:12+0000',
#   'from': {'id': '1266859913458317', 'name': 'Andreana Chou'},
#   'id': '782441068618572',
#   'message': 'No, movie night'},
#  {'created_time': '2018-02-24T23:27:04+0000',
#   'from': {'id': '10213485307185861', 'name': 'Eric Liang'},
#   'id': '782441641951848',
#   'message': 'nope, bowling/movies'},
#  {'created_time': '2018-02-24T23:27:41+0000',
#   'from': {'id': '1828224987189314', 'name': 'Vivian Tieu'},
#   'id': '782441771951835',
#   'message': 'Yes, board games, movie night, study sessions'},
#  {'created_time': '2018-02-24T23:28:07+0000',
#   'from': {'id': '1569646543153578', 'name': 'Michelle Leung'},
#   'id': '782441968618482',
#   'message': 'yes, ICE SKATING'},
#  {'created_time': '2018-02-24T23:28:40+0000',
#   'from': {'id': '1966986586649774', 'name': 'Kunal Gosar'},
#   'id': '782442225285123',
#   'message': 'Yes, poker+boardgames'},
#  {'created_time': '2018-02-24T23:29:11+0000',
#   'from': {'id': '1653422644718913', 'name': 'Andrew Low'},
#   'id': '782442418618437',
#   'message': 'No, shooting star'},
#  {'created_time': '2018-02-24T23:29:33+0000',
#   'from': {'id': '10211738622687035', 'name': 'Bill Zhou'},
#   'id': '782442555285090',
#   'message': 'No ice skating'},
#  {'created_time': '2018-02-24T23:29:42+0000',
#   'from': {'id': '845603538945677', 'name': 'Matt Chinn'},
#   'id': '782442615285084',
#   'message': 'No, ice skating/bowling!!'},
#  {'created_time': '2018-02-24T23:30:56+0000',
#   'from': {'id': '1841070009299755', 'name': 'Mina Tran'},
#   'id': '782444728618206',
#   'message': 'Yes, bowling'},
#  {'created_time': '2018-02-24T23:31:02+0000',
#   'from': {'id': '1690561534315880', 'name': 'Izzat Zuhailee'},
#   'id': '782444771951535',
#   'message': 'Yes, trip to sf!'},
#  {'created_time': '2018-02-24T23:33:10+0000',
#   'from': {'id': '1781581091886665', 'name': 'Case-y Takeda'},
#   'id': '782445295284816',
#   'message': 'no, ice skating + sf/oakland/albany trips + bowling + photowalks / photoshoots + hiking + escape room + board games + movie night with projector in dwinelle ? + down for a retreat lmfao'},
#  {'created_time': '2018-02-24T23:33:53+0000',
#   'from': {'id': '1970872972927428', 'name': 'Regina Xu'},
#   'id': '782445461951466',
#   'message': 'yes; boardgames, cooking/baking, sf photoshoot/day trip'},
#  {'created_time': '2018-02-24T23:34:00+0000',
#   'from': {'id': '10212597978288047', 'name': 'Jessica Ji'},
#   'id': '782445511951461',
#   'message': 'No; dance workshop, board game night, ice skating, anime marathon'},
#  {'created_time': '2018-02-24T23:34:43+0000',
#   'from': {'id': '965366800312927', 'name': 'Soo Rim Choi'},
#   'id': '782445821951430',
#   'message': 'yes; ice skating, board games'},
#  {'created_time': '2018-02-24T23:35:19+0000',
#   'from': {'id': '960979860716683', 'name': 'Alex Ro'},
#   'id': '782445968618082',
#   'message': 'Yes; movie night, sf trip'},
#  {'created_time': '2018-02-24T23:35:36+0000',
#   'from': {'id': '402822900142555', 'name': 'Jennifer Hwang'},
#   'id': '782446031951409',
#   'message': 'No, board games or movies'},
#  {'created_time': '2018-02-24T23:37:34+0000',
#   'from': {'id': '10204471685029284', 'name': 'Zhongxia Yan'},
#   'id': '782446441951368',
#   'message': 'no; boardgames, SF'},
#  {'created_time': '2018-02-24T23:38:12+0000',
#   'from': {'id': '10213680222778841', 'name': 'Claire Li'},
#   'id': '782446538618025',
#   'message': 'no, board games, bouldering'},
#  {'created_time': '2018-02-24T23:38:52+0000',
#   'from': {'id': '1937586706283369', 'name': 'Vicky Tu'},
#   'id': '782446658618013',
#   'message': 'No, ice skating!!'},
#  {'created_time': '2018-02-24T23:38:59+0000',
#   'from': {'id': '1815766928445412', 'name': 'Ying-An Wang'},
#   'id': '782446705284675',
#   'message': 'No, movie night'},
#  {'created_time': '2018-02-24T23:39:42+0000',
#   'from': {'id': '1554090614640858', 'name': 'George Zhou'},
#   'id': '782446831951329',
#   'message': 'No, board/card/group games'},
#  {'created_time': '2018-02-24T23:41:24+0000',
#   'from': {'id': '2009625185732721', 'name': 'Kai Zhou'},
#   'id': '782448438617835',
#   'message': 'yes! ice skating, movie night, sf/oakland photowalk, cooking together'},
#  {'created_time': '2018-02-24T23:41:58+0000',
#   'from': {'id': '1762234637162629', 'name': 'Raghav Verma'},
#   'id': '782448581951154',
#   'message': 'yes, basketball'},
#  {'created_time': '2018-02-24T23:42:11+0000',
#   'from': {'id': '1590005717701143', 'name': 'Catherine Chi'},
#   'id': '782448628617816',
#   'message': 'Yes, does assassins count as a social idea??'},
#  {'created_time': '2018-02-24T23:42:26+0000',
#   'from': {'id': '10215180662328318', 'name': 'Wesley Huang'},
#   'id': '782448688617810',
#   'message': 'Basketball board games video games'},
#  {'created_time': '2018-02-24T23:44:51+0000',
#   'from': {'id': '10215773805807242', 'name': 'Jonathan Tau'},
#   'id': '782449481951064',
#   'message': 'yes; board games / photography trip'},
#  {'created_time': '2018-02-24T23:47:41+0000',
#   'from': {'id': '878990605635887', 'name': 'Michelle Zhang'},
#   'id': '782450078617671',
#   'message': 'yes - anime/movie night'},
#  {'created_time': '2018-02-24T23:47:57+0000',
#   'from': {'id': '10208331094753586', 'name': 'Nancy Rose'},
#   'id': '782450151950997',
#   'message': 'yes, board games, trip to somewhere'},
#  {'created_time': '2018-02-24T23:51:25+0000',
#   'from': {'id': '1766018273443343', 'name': 'Arda Sahiner'},
#   'id': '782450885284257',
#   'message': 'yes, board games/poker'},
#  {'created_time': '2018-02-24T23:52:25+0000',
#   'from': {'id': '1860794233931289', 'name': 'Timothy Huang'},
#   'id': '782451061950906',
#   'message': 'yes, shopping trip!'},
#  {'created_time': '2018-02-24T23:55:18+0000',
#   'from': {'id': '1802661366459055', 'name': 'Stacey Chang'},
#   'id': '782451601950852',
#   'message': 'yes SKATE'},
#  {'created_time': '2018-02-24T23:55:28+0000',
#   'from': {'id': '2067273253299751', 'name': 'Shahrukh Shaikh'},
#   'id': '782451665284179',
#   'message': 'No, SF'},
#  {'created_time': '2018-02-24T23:58:07+0000',
#   'from': {'id': '10210787542946680', 'name': 'Richard Qian'},
#   'id': '782452205284125',
#   'message': 'hell yes, board games <3'},
#  {'created_time': '2018-02-25T00:00:44+0000',
#   'from': {'id': '1673512489360968', 'name': 'Cindy Chau'},
#   'id': '782452671950745',
#   'message': 'No; ^ board games pls :^)'},
#  {'created_time': '2018-02-25T00:14:02+0000',
#   'from': {'id': '1859995687344484', 'name': 'Marissa Wong'},
#   'id': '782456265283719',
#   'message': 'No ; board games, hikes, or foodie adventures ^^'},
#  {'created_time': '2018-02-25T00:16:19+0000',
#   'from': {'id': '10214595133090541', 'name': 'Cindy Yuan'},
#   'id': '782456811950331',
#   'message': 'ya, ice skating'},
#  {'created_time': '2018-02-25T00:16:48+0000',
#   'from': {'id': '1651842561566190', 'name': 'Alex Chang'},
#   'id': '782456881950324',
#   'message': 'No, board/party games night'},
#  {'created_time': '2018-02-25T00:22:42+0000',
#   'from': {'id': '2110982479138969', 'name': 'Divita Pandita'},
#   'id': '782458278616851',
#   'message': 'No; movie night'},
#  {'created_time': '2018-02-25T00:25:59+0000',
#   'from': {'id': '1557519804361395', 'name': 'Heather Held'},
#   'id': '782459285283417',
#   'message': 'baking!!'},
#  {'created_time': '2018-02-25T00:26:51+0000',
#   'from': {'id': '1419940264784295', 'name': 'Candace Chiang'},
#   'id': '782459391950073',
#   'message': 'No: rock climbingggg'},
#  {'created_time': '2018-02-25T00:30:16+0000',
#   'from': {'id': '2032711430280097', 'name': 'Meera Nagpal'},
#   'id': '782460018616677',
#   'message': 'no; hiking, board/other fun games, movies'},
#  {'created_time': '2018-02-25T01:09:43+0000',
#   'from': {'id': '1360560187423679', 'name': 'Aleksandra Ma'},
#   'id': '782472018615477',
#   'message': 'no, photoshoot!'},
#  {'created_time': '2018-02-25T01:19:38+0000',
#   'from': {'id': '2061199347240446', 'name': 'Frank Lee'},
#   'id': '782475881948424',
#   'message': 'yes, board-games or adventuring'},
#  {'created_time': '2018-02-25T01:29:42+0000',
#   'from': {'id': '10210341822773201', 'name': 'Bowen Wang'},
#   'id': '782477908614888',
#   'message': 'yes, food, sf/somewhere trip, ice skating'},
#  {'created_time': '2018-02-25T01:32:03+0000',
#   'from': {'id': '1804520206259908', 'name': 'Alex Lin'},
#   'id': '782478515281494',
#   'message': 'no. bowling, so the ball gets rolled instead of the party'},
#  {'created_time': '2018-02-25T01:33:20+0000',
#   'from': {'id': '1861098723902629', 'name': 'Calvin Zhou'},
#   'id': '782478701948142',
#   'message': 'Yes, board games'},
#  {'created_time': '2018-02-25T01:36:25+0000',
#   'from': {'id': '1611163545644720', 'name': 'Ethan Kau'},
#   'id': '782480171947995',
#   'message': 'No (just dropped stuff off), exploring/hiking'},
#  {'created_time': '2018-02-25T01:41:45+0000',
#   'from': {'id': '1634231789992507', 'name': 'Ivy Jasminne'},
#   'id': '782481671947845',
#   'message': 'No, bowling?'},
#  {'created_time': '2018-02-25T01:45:22+0000',
#   'from': {'id': '1752876814764627', 'name': 'Arnulfo Alvarez'},
#   'id': '782482671947745',
#   'message': 'No, Movie night?'},
#  {'created_time': '2018-02-25T02:03:31+0000',
#   'from': {'id': '10215790485781531', 'name': 'Katie Wu'},
#   'id': '782487621947250',
#   'message': 'yes, baking!!'},
#  {'created_time': '2018-02-25T02:21:37+0000',
#   'from': {'id': '1516337055154809', 'name': 'Julie Deng'},
#   'id': '782492428613436',
#   'message': 'no, movie night'},
#  {'created_time': '2018-02-25T02:28:10+0000',
#   'from': {'id': '945181255647060', 'name': 'Chris Cheung'},
#   'id': '782494098613269',
#   'message': 'yes, movie night!'},
#  {'created_time': '2018-02-25T02:40:04+0000',
#   'from': {'id': '1965004630181049', 'name': 'Jaymo Kang'},
#   'id': '782497168612962',
#   'message': 'Rock climbing'},
#  {'created_time': '2018-02-25T02:49:09+0000',
#   'from': {'id': '2006620479561102', 'name': 'Crystal Bai'},
#   'id': '782499431946069',
#   'message': 'no, movie night?'},
#  {'created_time': '2018-02-25T03:13:13+0000',
#   'from': {'id': '1049237601880581', 'name': 'Rohan Taori'},
#   'id': '782504898612189',
#   'message': 'no, bowling'},
#  {'created_time': '2018-02-25T03:57:56+0000',
#   'from': {'id': '2091652510861310', 'name': 'Bradley Chee'},
#   'id': '782515571944455',
#   'message': 'No, Bowling'},
#  {'created_time': '2018-02-25T04:25:34+0000',
#   'from': {'id': '1869887816378681', 'name': 'Olivia Koshy'},
#   'id': '782524925276853',
#   'message': 'no :((((( Hiking !!!'},
#  {'created_time': '2018-02-25T04:43:38+0000',
#   'from': {'id': '10213988397337562', 'name': 'Kevin Ji'},
#   'id': '782530641942948',
#   'message': 'Yes, ice skating, board games, escape room, group cooking, cycling in SF'},
#  {'created_time': '2018-02-25T04:59:51+0000',
#   'from': {'id': '1433533153422877', 'name': 'Ivon Liu'},
#   'id': '782542411941771',
#   'message': 'Yes, sf photo trip'},
#  {'created_time': '2018-02-25T05:37:10+0000',
#   'from': {'id': '1660434610669511', 'name': 'Max Feng'},
#   'id': '782554745273871',
#   'message': 'No, board games'},
#  {'created_time': '2018-02-25T05:45:47+0000',
#   'from': {'id': '801275703383449', 'name': 'Ewan Seo'},
#   'id': '782557775273568',
#   'message': 'No/board games or sf trip :)'},
#  {'created_time': '2018-02-25T06:01:53+0000',
#   'from': {'id': '985985398237133', 'name': 'Amanda Wang'},
#   'id': '782562871939725',
#   'message': 'No, board/card games'},
#  {'created_time': '2018-02-25T06:08:26+0000',
#   'from': {'id': '2147586932136301', 'name': 'Ciecie Chen'},
#   'id': '782564798606199',
#   'message': 'yes, sf trip and ice skating!'},
#  {'created_time': '2018-02-25T06:08:50+0000',
#   'from': {'id': '1952302455086786', 'name': 'Leela Amladi'},
#   'id': '782564935272852',
#   'message': 'No; chill/grill on the glade, bouldering'},
#  {'created_time': '2018-02-25T06:24:57+0000',
#   'from': {'id': '2040857309478302', 'name': 'Gary Li'},
#   'id': '782569915272354',
#   'message': 'No, board games!'},
#  {'created_time': '2018-02-25T06:28:53+0000',
#   'from': {'id': '1634231789992507', 'name': 'Ivy Jasminne'},
#   'id': '782571351938877',
#   'message': 'Poas Chou'},
#  {'created_time': '2018-02-25T06:30:24+0000',
#   'from': {'id': '10209646748440221', 'name': 'Poas Chou'},
#   'id': '782571761938836',
#   'message': 'No and smoking marijuana or hookah or both cuz I luv putting weed in my hookah!'},
#  {'created_time': '2018-02-25T06:32:53+0000',
#   'from': {'id': '10214341019226940', 'name': 'Michael Meng'},
#   'id': '782572725272073',
#   'message': 'yes, bowling or hiking!'},
#  {'created_time': '2018-02-25T06:35:45+0000',
#   'from': {'id': '1790295117689309', 'name': 'Ashley Holt'},
#   'id': '782573485271997',
#   'message': "No, Board Game/card game night or Movie night (basically anything that doesn't cost The Monies™)"},
#  {'created_time': '2018-02-25T07:01:02+0000',
#   'from': {'id': '10156136852832920', 'name': 'Mehdi Kazi'},
#   'id': '782580535271292',
#   'message': 'Yes, bowling or ice skating!'},
#  {'created_time': '2018-02-25T07:05:19+0000',
#   'from': {'id': '1816710241954743', 'name': 'Haixian Liao'},
#   'id': '782581745271171',
#   'message': 'No. Movie/board games/study/big c/hot pots'},
#  {'created_time': '2018-02-25T07:49:45+0000',
#   'from': {'id': '1836011243077323', 'name': 'Griffin Armstorff'},
#   'id': '782596925269653',
#   'message': 'Yes, beach bonfire'},
#  {'created_time': '2018-02-25T08:09:45+0000',
#   'from': {'id': '1970963762917320', 'name': 'Taylor Lee'},
#   'id': '782602838602395',
#   'message': 'No team hike?'},
#  {'created_time': '2018-02-25T08:14:45+0000',
#   'from': {'id': '10213717212918376', 'name': 'George Wu'},
#   'id': '782604241935588',
#   'message': 'Yes, ice skating'},
#  {'created_time': '2018-02-25T08:15:00+0000',
#   'from': {'id': '10215773805807242', 'name': 'Jonathan Tau'},
#   'id': '782604298602249',
#   'message': 'Skye Zhang'},
#  {'created_time': '2018-02-25T08:15:43+0000',
#   'from': {'id': '189333588465328', 'name': 'Skye Zhang'},
#   'id': '782604501935562',
#   'message': 'Yes paintball'},
#  {'created_time': '2018-02-25T09:36:05+0000',
#   'from': {'id': '1847389265294787', 'name': 'Dina Al-Hassani'},
#   'id': '782626871933325',
#   'message': 'No, more karoke lol, food adventures, and sf trips!'},
#  {'created_time': '2018-02-25T09:37:46+0000',
#   'from': {'id': '1619257478161162', 'name': 'Melissa Chien'},
#   'id': '782627295266616',
#   'message': 'no, board games'},
#  {'created_time': '2018-02-25T09:53:11+0000',
#   'from': {'id': '218367422045268', 'name': 'Tiffany E. Park'},
#   'id': '782631671932845',
#   'message': 'yes; bowling'},
#  {'created_time': '2018-02-25T10:59:56+0000',
#   'from': {'id': '10203858665344046', 'name': 'Boris Yue'},
#   'id': '782654605263885',
#   'message': 'Yes, bowling'},
#  {'created_time': '2018-02-25T18:01:05+0000',
#   'from': {'id': '10215662001450179', 'name': 'Greta Huang'},
#   'id': '782811238581555',
#   'message': 'No; ice skating'},
#  {'created_time': '2018-02-25T19:06:53+0000',
#   'from': {'id': '800121840173556', 'name': 'Boyce Buchanan'},
#   'id': '782829248579754',
#   'message': 'No. Movie night!'},
#  {'created_time': '2018-02-25T19:15:31+0000',
#   'from': {'id': '1235807543218232', 'name': 'Aidan Kahng'},
#   'id': '782831681912844',
#   'message': 'No. Taking over victory point cafe'},
#  {'created_time': '2018-02-25T21:24:18+0000',
#   'from': {'id': '555712454797999', 'name': 'Monica Oh'},
#   'id': '782866071909405',
#   'message': 'yas, ooh ice skating'},
#  {'created_time': '2018-02-25T21:37:43+0000',
#   'from': {'id': '2332365896789500', 'name': 'Cathy An'},
#   'id': '782869551909057',
#   'message': 'No. SF trip!'}]

# %%
def getNamesFromListOfComments(list_of_comments):
    responders = []
    for comment in list_of_comments:
        responders.append(comment["from"]["name"])
    return responders

responders = getNamesFromListOfComments(list_of_comments)
responders.sort()
responders
# Out:
# ['Aidan Kahng',
#  'Aleksandra Ma',
#  'Alex Chang',
#  'Alex Lin',
#  'Alex Ro',
#  'Amanda Wang',
#  'Andreana Chou',
#  'Andrew Low',
#  'Arda Sahiner',
#  'Arnulfo Alvarez',
#  'Ashley Holt',
#  'Bill Zhou',
#  'Boris Yue',
#  'Bowen Wang',
#  'Boyce Buchanan',
#  'Bradley Chee',
#  'Calvin Zhou',
#  'Candace Chiang',
#  'Case-y Takeda',
#  'Catherine Chi',
#  'Cathy An',
#  'Chris Cheung',
#  'Ciecie Chen',
#  'Cindy Chau',
#  'Cindy Yuan',
#  'Claire Li',
#  'Crystal Bai',
#  'Dina Al-Hassani',
#  'Divita Pandita',
#  'Eric Liang',
#  'Ethan Kau',
#  'Ewan Seo',
#  'Frank Lee',
#  'Gary Li',
#  'George Wu',
#  'George Zhou',
#  'Greta Huang',
#  'Griffin Armstorff',
#  'Haixian Liao',
#  'Heather Held',
#  'Ivon Liu',
#  'Ivy Jasminne',
#  'Ivy Jasminne',
#  'Izzat Zuhailee',
#  'Jackie Walia',
#  'Jaemin Kim',
#  'Jaymo Kang',
#  'Jennifer Hwang',
#  'Jessica Ji',
#  'Jessica Ji',
#  'Jonathan Tau',
#  'Jonathan Tau',
#  'Jones Ou',
#  'Julie Deng',
#  'Kai Zhou',
#  'Katie Crowe',
#  'Katie Wu',
#  'Kevin Ji',
#  'Kunal Gosar',
#  'Leela Amladi',
#  'Marissa Wong',
#  'Matt Chinn',
#  'Max Feng',
#  'Meera Nagpal',
#  'Mehdi Kazi',
#  'Melissa Chien',
#  'Michael Meng',
#  'Michelle Leung',
#  'Michelle Zhang',
#  'Mina Tran',
#  'Monica Oh',
#  'Nancy Rose',
#  'Olivia Koshy',
#  'Poas Chou',
#  'Raghav Verma',
#  'Regina Xu',
#  'Richard Qian',
#  'Rohan Taori',
#  'Shahrukh Shaikh',
#  'Skye Zhang',
#  'Soo Rim Choi',
#  'Stacey Chang',
#  'Taylor Lee',
#  'Tiffany E. Park',
#  'Timothy Huang',
#  'Vicky Tu',
#  'Victoria Park',
#  'Vincent Tantra',
#  'Vivian Tieu',
#  'Wesley Huang',
#  'Ying-An Wang',
#  'Zhongxia Yan']
