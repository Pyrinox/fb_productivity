# %%
from urllib.request import urlopen
import json
import datetime
import csv
import time

# %%
# app_id = "784490488408472"
# app_secret = "97035bf460ccc4734bd1ea2280534047"
# access_token = app_id + "|" + app_secret

access_token = "EAANl3Q6i6sQBANyUbwrKZANpJUrmgdrg4BRZBxVaIsIE41bLb24Dh8po8u7UNwpnWfvQTun2Y6K36IMQQwZB2hGhIaHEJt5XYINymiKwA4FEKyVja7H7ZBw5Df7riyiL0Bzk9ryO9VNY20ZBfVrpRJQllKVkjBQqPvTEBsfDNQl4OgPLZCTfAZCWolbwHHXBMEZD"

group_name = "afxlowkey"
# urlopen("https://graph.facebook.com/v2.12/me").read()

base = "https://graph.facebook.com/v2.12"
group_query = "/search?q=afxlowkey&type=group"
token = "&access_token=%s" % access_token

# parameters = "/?access_token=%s" % access_token
url = base + group_query + token
url
# Out:
# 'https://graph.facebook.com/v2.12/search?q=afxlowkey&type=group&access_token=EAALJfWzkKZAgBACDGJ7SWpGS6nbJB8XnpK2M2otvKw27OjMwhaEvVJeh1JjHCEbkqDbzEOIrCDIFhE7BOvxYBQGYdDDXHEN9Anu8gTKw7lYKMy9HsMga7OqzScZBPYreqLTmVPJTHDiWnvfxlCmC17HZCBZBUdIMzIMrtwmRoQZDZD'

# %%
# group_name is the name of the group as it appears in the url
# access_token can be attained from Graph API Explorer
def getGroupID(group_name, access_token):
    base = "https://graph.facebook.com/v2.12"
    group_query = "/search?q=%s&type=group" % group_name
    token = "&access_token=%s" % access_token
    url = base + group_query + token
    response = urlopen(url)
#     data = json.loads(resp)
#     return type(response.read())
    data = json.loads(response.read())
    return data["data"][0]["id"]

group_id = getGroupID(group_name, access_token)
group_id
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-da932199722b> in <module>()
#      12     return data["data"][0]["id"]
#      13
# ---> 14 group_id = getGroupID(group_name, access_token)
#      15 group_id
#
# <ipython-input-8-da932199722b> in getGroupID(group_name, access_token)
#      10 #     return type(response.read())
#      11     data = json.loads(response.read())
# ---> 12     return data["data"][0]["id"]
#      13
#      14 group_id = getGroupID(group_name, access_token)
#
# IndexError: list index out of range

# %%
def getPostIDs(group_id):
    base = "https://graph.facebook.com/v2.12/" + group_id
    group_query = "/feed?fields=name"
    token = "&access_token=%s" % access_token
    url = base + group_query + token
    response = urlopen(url)
    data = json.loads(response.read())
    list_of_dicts = data["data"]
    list_of_group_post_ids = [each["id"] for each in list_of_dicts]
    post_order_dict = {}
    iter_range = len(list_of_group_post_ids)
    for i in range(iter_range):
        back = list_of_group_post_ids.pop()
        post_order_dict[i+1] = back
    return post_order_dict
#     return data["data"]

getPostIDs(group_id)
# Out:
# {1: '771531489709530_781143315415014',
#  2: '771531489709530_781449528717726',
#  3: '771531489709530_781160542079958',
#  4: '771531489709530_781494235379922',
#  5: '771531489709530_778418549020824',
#  6: '771531489709530_780279948834684',
#  7: '771531489709530_781677292028283',
#  8: '771531489709530_781692568693422',
#  9: '771531489709530_782031345326211',
#  10: '771531489709530_782438615285484',
#  11: '771531489709530_783311905198155',
#  12: '771531489709530_783457378516941',
#  13: '771531489709530_782556048607074',
#  14: '771531489709530_783877128474966',
#  15: '771531489709530_784392488423430',
#  16: '771531489709530_784902328372446',
#  17: '771531489709530_785306394998706',
#  18: '771531489709530_785428478319831',
#  19: '771531489709530_784746418388037',
#  20: '771531489709530_787169081479104',
#  21: '771531489709530_785787304950615',
#  22: '771531489709530_787692618093417',
#  23: '771531489709530_788331141362898',
#  24: '771531489709530_788541321341880',
#  25: '771531489709530_789162921279720'}

# %%
def fuzzyStringComparison():
    return None

# %%
# string_identifier is a sample string from the post you're looking for.
# use only words (avoid emojis or other ill-formed units of meaning)
string_identifier = """
***READING QUESTION ACTION REQUIRED***
Hey team, thanks for your patience last practice with blocking! We will be continuing with blocking the mutexes (FTG/Goodies) at tomorrow’s practice!
"""

def findCorrectPost(group_id, string_identifier):
    base = "https://graph.facebook.com/v2.12/" + group_id
    group_query = "/feed?fields=name,message,comments"
    token = "&access_token=%s" % access_token
    url = base + group_query + token
#     print(url)
    response = urlopen(url)
    data = json.loads(response.read())
    correct_post = None
    for post in data["data"]:
#         print(type(list(post.keys())))
        if "message" not in list(post.keys()):
            continue
        check = post["message"]
        identical = False
        for word in string_identifier.split():
            if word not in check:
                break
            identical = True
        if identical:
            print(post["id"])
            correct_post = post
            break
#             print(word)
    
    return correct_post

correct_post = findCorrectPost(group_id, string_identifier)
correct_post
# Out:
# 771531489709530_787692618093417
# {'comments': {'data': [{'created_time': '2018-03-08T00:41:16+0000',
#     'from': {'id': '1965004630181049', 'name': 'Jaymo Kang'},
#     'id': '787692891426723',
#     'message': '71, Soo Rim Choi, Timothy Huang'},
#    {'created_time': '2018-03-08T00:41:45+0000',
#     'from': {'id': '1997465720283342', 'name': 'Katie Crowe'},
#     'id': '787692958093383',
#     'message': '25 i know that Kai Zhou and Jessica Ji are near me idk people’s names LMAOOOOOOOOO😥😥'},
#    {'created_time': '2018-03-08T00:44:10+0000',
#     'from': {'id': '1554090614640858', 'name': 'George Zhou'},
#     'id': '787693838093295',
#     'message': '64, Jonathan Tau (I think...) and Victoria Park (I think too...)'},
#    {'created_time': '2018-03-08T00:44:18+0000',
#     'from': {'id': '1781581091886665', 'name': 'Case-y Takeda'},
#     'id': '787693921426620',
#     'message': '57, Griffin Armstorff and Tiffany E. Park ?'},
#    {'created_time': '2018-03-08T00:44:25+0000',
#     'from': {'id': '2067273253299751', 'name': 'Shahrukh Shaikh'},
#     'id': '787693948093284',
#     'message': "84, wasn't present when we were situated :("},
#    {'created_time': '2018-03-08T00:44:53+0000',
#     'from': {'id': '1816710241954743', 'name': 'Haixian Liao'},
#     'id': '787694064759939',
#     'message': '67 Jonathan Tau Jennifer Hwang'},
#    {'created_time': '2018-03-08T00:45:32+0000',
#     'from': {'id': '10213485307185861', 'name': 'Eric Liang'},
#     'id': '787694194759926',
#     'message': '61, Griffin Armstorff and Melissa Chien i think :o'},
#    {'created_time': '2018-03-08T00:45:39+0000',
#     'from': {'id': '10213680222778841', 'name': 'Claire Li'},
#     'id': '787694258093253',
#     'message': '15, ...idk names 😳'},
#    {'created_time': '2018-03-08T00:46:25+0000',
#     'from': {'id': '1937586706283369', 'name': 'Vicky Tu'},
#     'id': '787694574759888',
#     'message': '37, Max Feng and someone else 😞'},
#  'name': 'AFX Spring 2018 Mid-Semester Evaluation'}

# %%
def getListOfComments(correct_post):
    
    # TRY BLOCK 1
    comments = []
    data = []
    # Method 1A: getting comments on current page
    try:
#         print("try1")
        data = correct_post["comments"]["data"]
        for comment in data:
            comments.append(comment)
#         print("hsdf", next_page_responders)
    except:
        pass
    
    # Method 2A: getting comments on current page
    try:
        data = correct_post["data"]
        for comment in data:
            comments.append(comment)
    except:
        pass
    
    # TRY BLOCK 2
    url = None
    # Method 1B: accessing the next page of responses
    try:
        url = correct_post["comments"]["paging"]["next"]
    except:
        pass
        
    try:
    # Method 2B: accessing the next page of responses
        url = correct_post["paging"]["next"]
    except:
        pass
    
    # Open the url (found by Method 1B/2B) if it exists.
    next_page_responders = []
    if url:
        response = urlopen(url)
        next_page = json.loads(response.read())
        next_page_responders = getListOfComments(next_page)
        comments.extend(next_page_responders)

    return comments
    

list_of_comments = getListOfComments(correct_post)
list_of_comments
# Out:
# [{'created_time': '2018-03-08T00:41:16+0000',
#   'from': {'id': '1965004630181049', 'name': 'Jaymo Kang'},
#   'id': '787692891426723',
#   'message': '71, Soo Rim Choi, Timothy Huang'},
#  {'created_time': '2018-03-08T00:41:45+0000',
#   'from': {'id': '1997465720283342', 'name': 'Katie Crowe'},
#   'id': '787692958093383',
#   'message': '25 i know that Kai Zhou and Jessica Ji are near me idk people’s names LMAOOOOOOOOO😥😥'},
#  {'created_time': '2018-03-08T00:44:10+0000',
#   'from': {'id': '1554090614640858', 'name': 'George Zhou'},
#   'id': '787693838093295',
#   'message': '64, Jonathan Tau (I think...) and Victoria Park (I think too...)'},
#  {'created_time': '2018-03-08T00:44:18+0000',
#   'from': {'id': '1781581091886665', 'name': 'Case-y Takeda'},
#   'id': '787693921426620',
#   'message': '57, Griffin Armstorff and Tiffany E. Park ?'},
#  {'created_time': '2018-03-08T00:44:25+0000',
#   'from': {'id': '2067273253299751', 'name': 'Shahrukh Shaikh'},
#   'id': '787693948093284',
#   'message': "84, wasn't present when we were situated :("},
#  {'created_time': '2018-03-08T00:44:53+0000',
#   'from': {'id': '1816710241954743', 'name': 'Haixian Liao'},
#   'id': '787694064759939',
#   'message': '67 Jonathan Tau Jennifer Hwang'},
#  {'created_time': '2018-03-08T00:45:32+0000',
#   'from': {'id': '10213485307185861', 'name': 'Eric Liang'},
#   'id': '787694194759926',
#   'message': '61, Griffin Armstorff and Melissa Chien i think :o'},
#  {'created_time': '2018-03-08T00:45:39+0000',
#   'from': {'id': '10213680222778841', 'name': 'Claire Li'},
#   'id': '787694258093253',
#   'message': '15, ...idk names 😳'},
#  {'created_time': '2018-03-08T00:46:25+0000',
#   'from': {'id': '1937586706283369', 'name': 'Vicky Tu'},
#   'id': '787694574759888',
#   'message': '37, Max Feng and someone else 😞'},
#  {'created_time': '2018-03-08T00:47:23+0000',
#   'from': {'id': '1660434610669511', 'name': 'Max Feng'},
#   'id': '787694741426538',
#   'message': '29, Vicky Tu Michelle Zhang'},
#  {'created_time': '2018-03-08T00:47:40+0000',
#   'from': {'id': '1836011243077323', 'name': 'Griffin Armstorff'},
#   'id': '787694821426530',
#   'message': '56 Case-y Takeda Eric Liang'},
#  {'created_time': '2018-03-08T00:47:58+0000',
#   'from': {'id': '1970963762917320', 'name': 'Taylor Lee'},
#   'id': '787694901426522',
#   'message': "87 - I'm terrible with names and will edit this comment in a minute"},
#  {'created_time': '2018-03-08T00:48:29+0000',
#   'from': {'id': '2061199347240446', 'name': 'Frank Lee'},
#   'id': '787694988093180',
#   'message': '18, Gary Li to the left?? Richard Qian in the front'},
#  {'created_time': '2018-03-08T00:48:58+0000',
#   'from': {'id': '2009625185732721', 'name': 'Kaiwen Zhou'},
#   'id': '787695151426497',
#   'message': '24, Jessica Ji and Jessica Ji are both near me'},
#  {'created_time': '2018-03-08T00:50:35+0000',
#   'from': {'id': '1569646543153578', 'name': 'Michelle Leung'},
#   'id': '787695748093104',
#   'message': '79 left Raghav Verma right Eric Liang'},
#  {'created_time': '2018-03-08T00:54:06+0000',
#   'from': {'id': '2040857309478302', 'name': 'Gary Li'},
#   'id': '787696691426343',
#   'message': '19, Bill Zhou and Frank Lee'},
#  {'created_time': '2018-03-08T00:54:28+0000',
#   'from': {'id': '2091652510861310', 'name': 'Bradley Chee'},
#   'id': '787696774759668',
#   'message': '56 (i think), Victoria Park and Katie Wu behind somewhere'},
#  {'created_time': '2018-03-08T00:54:44+0000',
#   'from': {'id': '10209646748440221', 'name': 'Poas Chou'},
#   'id': '787697194759626',
#   'message': '81 Katie Wu and Raghav Verma'},
#  {'created_time': '2018-03-08T00:57:02+0000',
#   'from': {'id': '960979860716683', 'name': 'Alex Ro'},
#   'id': '787697758092903',
#   'message': '4, Kevin Ji and Nancy Rose'},
#  {'created_time': '2018-03-08T01:00:19+0000',
#   'from': {'id': '189333588465328', 'name': 'Skye Zhang'},
#   'id': '787698464759499',
#   'message': '36 纪天逍 and Calvin Zhou'},
#  {'created_time': '2018-03-08T01:04:05+0000',
#   'from': {'id': '1651842561566190', 'name': 'Alex Chang'},
#   'id': '787699368092742',
#   'message': '48, Timothy Huang and Cindy Chau'},
#  {'created_time': '2018-03-08T01:04:54+0000',
#   'from': {'id': '10208331094753586', 'name': 'Nancy Rose'},
#   'id': '787699531426059',
#   'message': '47 Alex Ro and Aidan Kahng'},
#  {'created_time': '2018-03-08T01:05:20+0000',
#   'from': {'id': '1365145640257061', 'name': 'Jessica Ji'},
#   'id': '787699618092717',
#   'message': '43 Richard Qian front left Kai Zhou back right'},
#  {'created_time': '2018-03-08T01:05:38+0000',
#   'from': {'id': '1235807543218232', 'name': 'Aidan Kahng'},
#   'id': '787699694759376',
#   'message': '1, Nancy Rose and Monica?'},
#  {'created_time': '2018-03-08T01:07:54+0000',
#   'from': {'id': '1752876814764627', 'name': 'Arnulfo Alvarez'},
#   'id': '787700351425977',
#   'message': '8, Wes (?), Mehdi Kazi'},
#  {'created_time': '2018-03-08T01:10:15+0000',
#   'from': {'id': '10156136852832920', 'name': 'Mehdi Kazi'},
#   'id': '787701321425880',
#   'message': '31, Ciecie Chen and Arnulfo Alvarez'},
#  {'created_time': '2018-03-08T04:21:50+0000',
#   'from': {'id': '10215180662328318', 'name': 'Wesley Huang'},
#   'id': '787753234754022',
#   'message': '39 Jackie Walia and Arnulfo Alvarez'},
#  {'created_time': '2018-03-08T04:30:31+0000',
#   'from': {'id': '1049237601880581', 'name': 'Rohan Taori'},
#   'id': '787757148086964',
#   'message': '35 - Richard and uhhhh'},
#  {'created_time': '2018-03-08T04:37:19+0000',
#   'from': {'id': '1266859913458317', 'name': 'Andreana Chou'},
#   'id': '787758774753468',
#   'message': '6 Amanda Wang and Kevin Ji'},
#  {'created_time': '2018-03-08T05:00:28+0000',
#   'from': {'id': '2032711430280097', 'name': 'Meera Nagpal'},
#   'id': '787768981419114',
#   'message': '30 Monica Oh & Max Feng'},
#  {'created_time': '2018-03-08T05:07:23+0000',
#   'from': {'id': '1841070009299755', 'name': 'Mina Tran'},
#   'id': '787771014752244',
#   'message': '80 Cindy Chau and no one on left'},
#  {'created_time': '2018-03-08T05:12:26+0000',
#   'from': {'id': '1828224987189314', 'name': 'Vivian Tieu'},
#   'id': '787772298085449',
#   'message': '38 Ethan Kau and Regina Xu'},
#  {'created_time': '2018-03-08T05:34:46+0000',
#   'from': {'id': '1861098723902629', 'name': 'Calvin Zhou'},
#   'id': '787777061418306',
#   'message': '41 Skye Zhang and Andrew Ng'},
#  {'created_time': '2018-03-08T05:53:20+0000',
#   'from': {'id': '1419940264784295', 'name': 'Candace Chiang'},
#   'id': '787781618084517',
#   'message': '56 Victoria Park Julie Deng'},
#  {'created_time': '2018-03-08T06:04:18+0000',
#   'from': {'id': '985985398237133', 'name': 'Amanda Wang'},
#   'id': '787784464750899',
#   'message': '5, Andreana Chou and Ashley Holt'},
#  {'created_time': '2018-03-08T06:15:56+0000',
#   'from': {'id': '10210787542946680', 'name': 'Richard Qian'},
#   'id': '787788731417139',
#   'message': '45, Rohan Taori back left, Jessica Ji back right'},
#  {'created_time': '2018-03-08T06:16:58+0000',
#   'from': {'id': '800121840173556', 'name': 'Boyce Buchanan'},
#   'id': '787789091417103',
#   'message': '54 Boris Yue and Crystal Bai'},
#  {'created_time': '2018-03-08T06:20:23+0000',
#   'from': {'id': '1802661366459055', 'name': 'Stacey Chang'},
#   'id': '787790601416952',
#   'message': '86? next to candace and behind louisa 3'},
#  {'created_time': '2018-03-08T06:21:00+0000',
#   'from': {'id': '10212597978288047', 'name': 'Jessica Ji'},
#   'id': '787790814750264',
#   'message': '22 Richard Qian Kai Zhou'},
#  {'created_time': '2018-03-08T06:21:56+0000',
#   'from': {'id': '2110982479138969', 'name': 'Divita Pandita'},
#   'id': '787791111416901',
#   'message': "I wasn't feeling well and had to leave practice early😓😓"},
#  {'created_time': '2018-03-08T06:31:58+0000',
#   'from': {'id': '1815766928445412', 'name': 'Ying-An Wang'},
#   'id': '787796324749713',
#   'message': '92, Arda Sahiner and Mina Tran'},
#  {'created_time': '2018-03-08T06:39:21+0000',
#   'from': {'id': '2006620479561102', 'name': 'Crystal Bai'},
#   'id': '787798781416134',
#   'message': '60, Boyce Buchanan and Soo Rim Choi'},
#  {'created_time': '2018-03-08T07:41:26+0000',
#   'from': {'id': '10214341019226940', 'name': 'Michael Meng'},
#   'id': '787816001414412',
#   'message': '(48 i think?) in b/w Poas Chou and Griffin Armstorff'},
#  {'created_time': '2018-03-08T08:04:05+0000',
#   'from': {'id': '1952302455086786', 'name': 'Leela Amladi'},
#   'id': '787821798080499',
#   'message': '27 Matt Chinn Gary Li'},
#  {'created_time': '2018-03-08T09:11:25+0000',
#   'from': {'id': '945181255647060', 'name': 'Chris Cheung'},
#   'id': '787840311411981',
#   'message': '58 Katie Wu Shahrukh Shaikh'},
#  {'created_time': '2018-03-08T09:12:10+0000',
#   'from': {'id': '965366800312927', 'name': 'Soo Rim Choi'},
#   'id': '787840524745293',
#   'message': '85, Crystal Bai and Timothy Huang'},
#  {'created_time': '2018-03-08T09:48:54+0000',
#   'from': {'id': '10215662001450179', 'name': 'Greta Huang'},
#   'id': '787852698077409',
#   'message': '65, George Zhou and someone else 😅'},
#  {'created_time': '2018-03-08T15:48:12+0000',
#   'from': {'id': '1869887816378681', 'name': 'Olivia Koshy'},
#   'id': '787998368062842',
#   'message': '33, Vicky Tu, Aleksandra Ma'},
#  {'created_time': '2018-03-08T15:53:18+0000',
#   'from': {'id': '2062952267322815', 'name': 'Vincent Tantra'},
#   'id': '787999638062715',
#   'message': '91, Alex Chang, Timothy Huang'},
#  {'created_time': '2018-03-08T16:45:26+0000',
#   'from': {'id': '801275703383449', 'name': 'Ewan Seo'},
#   'id': '788017271394285',
#   'message': '62, Ivon Liu Anastasia Vela'},
#  {'created_time': '2018-03-08T17:54:44+0000',
#   'from': {'id': '10211738622687035', 'name': 'Bill Zhou'},
#   'id': '788043634724982',
#   'message': '10 @heather Gary Li Kai Zhou'},
#  {'created_time': '2018-03-08T18:16:46+0000',
#   'from': {'id': '218367422045268', 'name': 'Tiffany E. Park'},
#   'id': '788048774724468',
#   'message': '88 casey bradley'},
#  {'created_time': '2018-03-08T19:34:05+0000',
#   'from': {'id': '1966986586649774', 'name': 'Kunal Gosar'},
#   'id': '788069601389052',
#   'message': '76 Ewan Seo George Wu'},
#  {'created_time': '2018-03-08T22:04:29+0000',
#   'from': {'id': '10213717212918376', 'name': 'George Wu'},
#   'id': '788116974717648',
#   'message': '63 michelle, michael'},
#  {'created_time': '2018-03-09T02:24:23+0000',
#   'from': {'id': '10213988397337562', 'name': 'Kevin Ji'},
#   'id': '788189571377055',
#   'message': '26 Vicky Tu Alex Ro Andreana Chou'},
#  {'created_time': '2018-03-09T03:32:21+0000',
#   'from': {'id': '1804520206259908', 'name': 'Alex Lin'},
#   'id': '788208204708525',
#   'message': '3 Aleksandra Devita'},
#  {'created_time': '2018-03-09T05:07:37+0000',
#   'from': {'id': '2332365896789500', 'name': 'Cathy An'},
#   'id': '788233108039368',
#   'message': "12, don't remember their names :'("}]

# %%
def getNamesFromListOfComments(list_of_comments):
    responders = []
    for comment in list_of_comments:
        responders.append(comment["from"]["name"])
    return responders

responders = getNamesFromListOfComments(list_of_comments)
# len(responders)
responders
# Out:
# ['Jaymo Kang',
#  'Katie Crowe',
#  'George Zhou',
#  'Case-y Takeda',
#  'Shahrukh Shaikh',
#  'Haixian Liao',
#  'Eric Liang',
#  'Claire Li',
#  'Vicky Tu',
#  'Max Feng',
#  'Griffin Armstorff',
#  'Taylor Lee',
#  'Frank Lee',
#  'Kaiwen Zhou',
#  'Michelle Leung',
#  'Gary Li',
#  'Bradley Chee',
#  'Poas Chou',
#  'Alex Ro',
#  'Skye Zhang',
#  'Alex Chang',
#  'Nancy Rose',
#  'Jessica Ji',
#  'Aidan Kahng',
#  'Arnulfo Alvarez',
#  'Mehdi Kazi',
#  'Katie Wu',
#  'Melissa Chien',
#  'Ethan Kau',
#  'Raghav Verma',
#  'Jaemin Kim',
#  'Jennifer Hwang',
#  'Jonathan Tau',
#  'Ivon Liu',
#  'Monica Oh',
#  'Victoria Park',
#  'Regina Xu',
#  'Heather Held',
#  'Matt Chinn',
#  'Andrew Low',
#  'Boris Yue',
#  'Arda Sahiner',
#  'Julie Deng',
#  'Aleksandra Ma',
#  'Jackie Walia',
#  'Cindy Chau',
#  'Ciecie Chen',
#  'Izzat Zuhailee',
#  'Andrew Ng',
#  'Timothy Huang',
#  'Michelle Zhang',
#  'Ashley Holt',
#  'Zhongxia Yan',
#  'Catherine Chi',
#  'Anastasia Vela',
#  'Cindy Yuan',
#  'Bowen Wang',
#  'Dina Al-Hassani',
#  'Wesley Huang',
#  'Rohan Taori',
#  'Andreana Chou',
#  'Meera Nagpal',
#  'Mina Tran',
#  'Vivian Tieu',
#  'Calvin Zhou',
#  'Candace Chiang',
#  'Amanda Wang',
#  'Richard Qian',
#  'Boyce Buchanan',
#  'Stacey Chang',
#  'Jessica Ji',
#  'Divita Pandita',
#  'Ying-An Wang',
#  'Crystal Bai',
#  'Michael Meng',
#  'Leela Amladi',
#  'Chris Cheung',
#  'Soo Rim Choi',
#  'Greta Huang',
#  'Olivia Koshy',
#  'Vincent Tantra',
#  'Ewan Seo',
#  'Bill Zhou',
#  'Tiffany E. Park',
#  'Kunal Gosar',
#  'George Wu',
#  'Kevin Ji',
#  'Alex Lin',
#  'Cathy An']

# %%
def getListOfResponders(correct_post):
    responders = []
    for comment in correct_post["comments"]["data"]:
        responders.append(comment["from"]["name"])
    return responders

responders = getListOfResponders(correct_post)
# responders.sort()
responders
# Out:
# ['Jaymo Kang',
#  'Katie Crowe',
#  'George Zhou',
#  'Case-y Takeda',
#  'Shahrukh Shaikh',
#  'Haixian Liao',
#  'Eric Liang',
#  'Claire Li',
#  'Vicky Tu',
#  'Max Feng',
#  'Griffin Armstorff',
#  'Taylor Lee',
#  'Frank Lee',
#  'Kaiwen Zhou',
#  'Michelle Leung',
#  'Gary Li',
#  'Bradley Chee',
#  'Poas Chou',
#  'Alex Ro',
#  'Skye Zhang',
#  'Alex Chang',
#  'Nancy Rose',
#  'Jessica Ji',
#  'Aidan Kahng',
#  'Arnulfo Alvarez']

# %%
getGroupID(group_name, access_token)
# Out:
# '771531489709530'

# %%
def testFacebookGroupData(group_id, access_token):
#     base = "https://graph.facebook.com/v2.12"
#     node = "/search?q=" + group_id
#     parameters = "/&type=group&access_token=%s" % access_token
    url = "https://graph.facebook.com/v2.12/771531489709530/feed?fields=name&access_token=EAALJfWzkKZAgBACDGJ7SWpGS6nbJB8XnpK2M2otvKw27OjMwhaEvVJeh1JjHCEbkqDbzEOIrCDIFhE7BOvxYBQGYdDDXHEN9Anu8gTKw7lYKMy9HsMga7OqzScZBPYreqLTmVPJTHDiWnvfxlCmC17HZCBZBUdIMzIMrtwmRoQZDZD"

#     url = base + node + parameters
    
    # retrieve data
    response = urlopen(url)
    data = json.loads(response.read())
    
    print(data)

# %%
testFacebookGroupData(group_id, access_token)
# Out:
# {'data': [{'id': '771531489709530_773784409484238'}, {'name': 'LoWKey want to get to know you!', 'id': '771531489709530_774127822783230'}, {'id': '771531489709530_773875559475123'}, {'id': '771531489709530_772063739656305'}, {'id': '771531489709530_772063069656372'}, {'id': '771531489709530_771531493042863'}], 'paging': {'previous': 'https://graph.facebook.com/v2.12/771531489709530/feed?fields=name&icon_size=16&since=1518049306&access_token=EAALJfWzkKZAgBACDGJ7SWpGS6nbJB8XnpK2M2otvKw27OjMwhaEvVJeh1JjHCEbkqDbzEOIrCDIFhE7BOvxYBQGYdDDXHEN9Anu8gTKw7lYKMy9HsMga7OqzScZBPYreqLTmVPJTHDiWnvfxlCmC17HZCBZBUdIMzIMrtwmRoQZDZD&limit=25&__paging_token=enc_AdCItUTYEbpBg1KOnecH8efaczHQ5GTVpz1nzqVfMBfRB2ez4G4Rt7TDCYrgNXrMDse3burKVoIZAUZAI0ZBkiIcyWaDDr2rosZAGlUEdMAt35BsLgZDZD&__previous=1', 'next': 'https://graph.facebook.com/v2.12/771531489709530/feed?fields=name&icon_size=16&access_token=EAALJfWzkKZAgBACDGJ7SWpGS6nbJB8XnpK2M2otvKw27OjMwhaEvVJeh1JjHCEbkqDbzEOIrCDIFhE7BOvxYBQGYdDDXHEN9Anu8gTKw7lYKMy9HsMga7OqzScZBPYreqLTmVPJTHDiWnvfxlCmC17HZCBZBUdIMzIMrtwmRoQZDZD&limit=25&until=1517446564&__paging_token=enc_AdDX1ZANBVUHm9MBrOitdZAD6lRZAfyNZCScMD0EqI08RzhQCkvnp4jbxXj23jurtNbAKJrZA9pbZAA1DIyqT5FEZCeyc2AwQCL4BtxgJHSeCVPR8RhPQZDZD'}}

# %%
access_token = app_id + "|" + app_secret
page_id = 'nytimes'
def testFacebookPageData(page_id, access_token):
    
    # construct the URL string
    base = "https://graph.facebook.com/v2.4"
    node = "/" + page_id
    parameters = "/?access_token=%s" % access_token
    url = base + node + parameters
    
    # retrieve data
#     req = urlopen(url)
    response = urlopen(url)
    data = json.loads(response.read())
    
    print(json.dumps(data, indent=4, sort_keys=True))
    

testFacebookPageData(page_id, access_token)
# Out:
# {
#     "id": "5281959998",
#     "name": "The New York Times"
# }

# %%
curl -i -X GET \
 "https://graph.facebook.com/v2.12/771531489709530/feed?fields=name&access_token=EAALJfWzkKZAgBACDGJ7SWpGS6nbJB8XnpK2M2otvKw27OjMwhaEvVJeh1JjHCEbkqDbzEOIrCDIFhE7BOvxYBQGYdDDXHEN9Anu8gTKw7lYKMy9HsMga7OqzScZBPYreqLTmVPJTHDiWnvfxlCmC17HZCBZBUdIMzIMrtwmRoQZDZD"
